# %%
# 1. Check if eligible to vote
age = int(input())
if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
#  43
# Eligible to vote

# %%
# 1. Check if eligible to vote
age = int(input())
if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
#  12
# Not eligible to vote

# %%
# 2. Even or Odd
n = int(input("Enter number: "))
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number:  8
# Even

# %%
# 2. Even or Odd
n = int(input("Enter number: "))
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number:  5
# Odd

# %%
# 3. Divisible by 5 or not
n = int(input())
if n % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
#  35
# Yes

# %%
# 3. Divisible by 5 or not
n = int(input())
if n % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
#  67
# No

# %%
# 5. Print last digit
n = int(input())
print(n % 10)
# Out:
#  345
# 5
