# %%
# a
length = 10
breadth = 20

# b
sum = (length + breadth) / 2

# c
stationery = ['Paper', 'Gel Pen', 'Eraser']

# d
first = "Mohandas"
middle = "Karamchand"
last = "Gandhi"

# e
fullname = first + " " + middle + " " + last

# %%
# WAP to find average of three no.
n1 = float(input())
n2 = float(input())
n3 = float(input())

avg = (n1 + n2 + n3) / 3
print("Average =", avg)
# Out:
#  1
#  2
#  3
# Average = 2.0

# %%
# WAAP to Find the Year When User Turns 100
name = input("Enter your name: ")
age = int(input("Enter your age: "))

year = 2026
year_100 = year + (100 - age)

print(name, "You will turn 100 years old in the year", year_100)
# Out:
# Enter your name:  Siraj
# Enter your age:  24
# Siraj You will turn 100 years old in the year 2102

# %%
country = "INDIA"
print(country)
# Out:
# INDIA
