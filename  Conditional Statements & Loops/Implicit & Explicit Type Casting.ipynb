# %%
num1 = 4
num2 = 3
num3 = 2

# A
num1 += num2 + num3
print(num1)

# B
numB = num1 ** (num2 + num3)
print(numB)

# c
numC = num1 ** num2 + numB

# D
numD = 5 + 5
print(numD)

# E
print(4.00 / (2.0 + 2.0))

# F
numF = 2 + 9 * ((3 * 12) - 8) / 10
print(numF)

# G
numG = float(10)
print(numG)

# H
numH = int(float('3.14'))
print(numH)
# Out:
# 9
# 59049
# 10
# 1.0
# 27.2
# 10.0
# 3
